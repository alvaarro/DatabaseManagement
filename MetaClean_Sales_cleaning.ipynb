# %%
import pandas as pd
df_sales = pd.read_excel(r'C:\Users\memwa\Desktop\Database Management\Partially cleaned data\sales.xlsx')
df_movies = pd.read_excel(r'C:\Users\memwa\Desktop\Database Management\Partially cleaned data\metaClean43Brightspace.xlsx')

# %%
df_sales.head()
df_sales.columns
# Out:
# Index(['year', 'release_date', 'title', 'genre', 'international_box_office',
#        'domestic_box_office', 'worldwide_box_office ', 'production_budget',
#        'Unnamed: 8', 'opening_weekend', 'theatre_count', 'avg run per theatre',
#        'runtime', 'keywords', 'creative_type', 'url'],
#       dtype='object')

# %%
df_sales.head()
# Out:
#    year     release_date                title              genre  \
# 0  2000      January 1st         Bakha Satang              Drama
# 1  2001     January 12th            Antitrust  Thriller/Suspense
# 2  2000     January 28th             Santitos                NaN
# 3  2002  2002 (Wide) by   Frank McKlusky C.I.                NaN
# 4  2002     January 25th   A Walk to Remember              Drama
#
#    international_box_office  domestic_box_office  worldwide_box_office   \
# 0                   76576.0                  NaN                76576.0
# 1                 6900000.0           10965209.0             17865209.0
# 2                       NaN             378562.0                    NaN
# 3                       NaN                  NaN                    NaN
# 4                 4833792.0           41227069.0             46060861.0
#
#    production_budget  Unnamed: 8  opening_weekend  theatre_count  \
# 0                NaN         NaN              NaN            NaN
# 1         30000000.0         NaN        5486209.0         2433.0
# 2                NaN         NaN              NaN            NaN
# 3                NaN         NaN              NaN            NaN
# 4         11000000.0         NaN       12177488.0         2411.0
#
#    avg run per theatre  runtime       keywords         creative_type  \
# 0                  NaN    129.0            NaN  Contemporary Fiction
# 1                  3.1      NaN            NaN  Contemporary Fiction
# 2                  NaN    105.0            NaN                   NaN
# 3                  NaN      NaN            NaN                   NaN
# 4                  5.3      NaN  Coming of Age  Contemporary Fiction
#
#                                                  url
# 0  https://www.the-numbers.com/movie/Bakha-Satang...
# 1        https://www.the-numbers.com/movie/Antitrust
# 2         https://www.the-numbers.com/movie/Santitos
# 3  https://www.the-numbers.com/movie/Frank-McKlus...
# 4  https://www.the-numbers.com/movie/Walk-to-Reme...

# %%
df_sales = df_sales[['year', 'release_date','title', 'genre','worldwide_box_office ','production_budget','url']]
df_sales.head()
# Out:
#    year     release_date                title              genre  \
# 0  2000      January 1st         Bakha Satang              Drama
# 1  2001     January 12th            Antitrust  Thriller/Suspense
# 2  2000     January 28th             Santitos                NaN
# 3  2002  2002 (Wide) by   Frank McKlusky C.I.                NaN
# 4  2002     January 25th   A Walk to Remember              Drama
#
#    worldwide_box_office   production_budget  \
# 0                76576.0                NaN
# 1             17865209.0         30000000.0
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4             46060861.0         11000000.0
#
#                                                  url
# 0  https://www.the-numbers.com/movie/Bakha-Satang...
# 1        https://www.the-numbers.com/movie/Antitrust
# 2         https://www.the-numbers.com/movie/Santitos
# 3  https://www.the-numbers.com/movie/Frank-McKlus...
# 4  https://www.the-numbers.com/movie/Walk-to-Reme...

# %%
df_sales.isnull().sum()
# Out:
# year                         0
# release_date                 0
# title                        8
# genre                     1704
# worldwide_box_office      9037
# production_budget        26132
# url                          0
# dtype: int64

# %%
df_sales['title'] = df_sales['title'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
df_sales['genre'] = df_sales['genre'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)

# %%
df_sales.drop_duplicates(subset = 'title', keep='last')
df_sales.head()
# Out:
#    year     release_date               title             genre  \
# 0  2000      January 1st        Bakha Satang             Drama
# 1  2001     January 12th           Antitrust  ThrillerSuspense
# 2  2000     January 28th            Santitos               NaN
# 3  2002  2002 (Wide) by    Frank McKlusky CI               NaN
# 4  2002     January 25th  A Walk to Remember             Drama
#
#    worldwide_box_office   production_budget  \
# 0                76576.0                NaN
# 1             17865209.0         30000000.0
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4             46060861.0         11000000.0
#
#                                                  url
# 0  https://www.the-numbers.com/movie/Bakha-Satang...
# 1        https://www.the-numbers.com/movie/Antitrust
# 2         https://www.the-numbers.com/movie/Santitos
# 3  https://www.the-numbers.com/movie/Frank-McKlus...
# 4  https://www.the-numbers.com/movie/Walk-to-Reme...

# %%
df_sales = df_sales.fillna({'genre': 'Unknown'})
df_sales.head()
# Out:
#    year     release_date               title             genre  \
# 0  2000      January 1st        Bakha Satang             Drama
# 1  2001     January 12th           Antitrust  ThrillerSuspense
# 2  2000     January 28th            Santitos           Unknown
# 3  2002  2002 (Wide) by    Frank McKlusky CI           Unknown
# 4  2002     January 25th  A Walk to Remember             Drama
#
#    worldwide_box_office   production_budget  \
# 0                76576.0                NaN
# 1             17865209.0         30000000.0
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4             46060861.0         11000000.0
#
#                                                  url
# 0  https://www.the-numbers.com/movie/Bakha-Satang...
# 1        https://www.the-numbers.com/movie/Antitrust
# 2         https://www.the-numbers.com/movie/Santitos
# 3  https://www.the-numbers.com/movie/Frank-McKlus...
# 4  https://www.the-numbers.com/movie/Walk-to-Reme...

# %%
df_sales = df_sales.fillna(value = 0)
df_sales.head()
# Out:
#    year     release_date               title             genre  \
# 0  2000      January 1st        Bakha Satang             Drama
# 1  2001     January 12th           Antitrust  ThrillerSuspense
# 2  2000     January 28th            Santitos           Unknown
# 3  2002  2002 (Wide) by    Frank McKlusky CI           Unknown
# 4  2002     January 25th  A Walk to Remember             Drama
#
#    worldwide_box_office   production_budget  \
# 0                76576.0                0.0
# 1             17865209.0         30000000.0
# 2                    0.0                0.0
# 3                    0.0                0.0
# 4             46060861.0         11000000.0
#
#                                                  url
# 0  https://www.the-numbers.com/movie/Bakha-Satang...
# 1        https://www.the-numbers.com/movie/Antitrust
# 2         https://www.the-numbers.com/movie/Santitos
# 3  https://www.the-numbers.com/movie/Frank-McKlus...
# 4  https://www.the-numbers.com/movie/Walk-to-Reme...

# %%
excel_file = r'C:\Users\memwa\Desktop\cleaned_data\sales_cleaned.xlsx'
df_sales.to_excel(excel_file, index=False)

# %%
df_movies.head()
# Out:
#                                                  url                  title  \
# 0  https://www.metacritic.com/movie/!women-art-re...  !Women Art Revolution
# 1  https://www.metacritic.com/movie/10-cloverfiel...    10 Cloverfield Lane
# 2  https://www.metacritic.com/movie/10-items-or-less       10 Items or Less
# 3          https://www.metacritic.com/movie/10-years               10 Years
# 4  https://www.metacritic.com/movie/100-bloody-acres       100 Bloody Acres
#
#                      studio       rating  runtime  \
# 0       Hotwire Productions  | Not Rated     83.0
# 1        Paramount Pictures      | PG-13    104.0
# 2                Click Star          | R     82.0
# 3  Anchor Bay Entertainment          | R    100.0
# 4           Music Box Films  | Not Rated     91.0
#
#                                                 cast              director  \
# 0                                                NaN  Lynn Hershman-Leeson
# 1  John Gallagher Jr.,John Goodman,Mary Elizabeth...      Dan Trachtenberg
# 2                 Jonah Hill,Morgan Freeman,Paz Vega       Brad Silberling
# 3             Channing Tatum,Chris Pratt,Jenna Dewan          Jamie Linden
# 4                                                NaN       Cameron Cairnes
#
#                                          genre  \
# 0                                  Documentary
# 1  Action,Sci-Fi,Drama,Mystery,Thriller,Horror
# 2                         Drama,Comedy,Romance
# 3                         Drama,Comedy,Romance
# 4                                Horror,Comedy
#
#                                              summary  \
# 0                                                NaN
# 1  Waking up from a car accident, a young woman (...
# 2  While researching a role as a supermarket mana...
# 3                                                NaN
# 4  Reg and Lindsay run an organic fertilizer busi...
#
#                                               awards  metascore  userscore  \
# 0                                                NaN         70        NaN
# 1  #18MostDiscussedMovieof2016 , #1MostSharedMovi...         76        7.7
# 2                                                NaN         54        5.8
# 3                                                NaN         61        6.9
# 4                                                NaN         63        7.5
#
#      RelDate
# 0 2011-06-01
# 1 2016-03-11
# 2 2006-12-01
# 3 2012-09-14
# 4 2013-06-28

# %%
df_movies.columns
# Out:
# Index(['url', 'title', 'studio', 'rating', 'runtime', 'cast', 'director',
#        'genre', 'summary', 'awards', 'metascore', 'userscore', 'RelDate'],
#       dtype='object')

# %%
df_movies = df_movies[['url', 'title', 'studio', 'rating', 'cast', 'director',
       'genre', 'userscore', 'RelDate']]

# %%
df_movies.head()
# Out:
#                                                  url                  title  \
# 0  https://www.metacritic.com/movie/!women-art-re...  !Women Art Revolution
# 1  https://www.metacritic.com/movie/10-cloverfiel...    10 Cloverfield Lane
# 2  https://www.metacritic.com/movie/10-items-or-less       10 Items or Less
# 3          https://www.metacritic.com/movie/10-years               10 Years
# 4  https://www.metacritic.com/movie/100-bloody-acres       100 Bloody Acres
#
#                      studio       rating  \
# 0       Hotwire Productions  | Not Rated
# 1        Paramount Pictures      | PG-13
# 2                Click Star          | R
# 3  Anchor Bay Entertainment          | R
# 4           Music Box Films  | Not Rated
#
#                                                 cast              director  \
# 0                                                NaN  Lynn Hershman-Leeson
# 1  John Gallagher Jr.,John Goodman,Mary Elizabeth...      Dan Trachtenberg
# 2                 Jonah Hill,Morgan Freeman,Paz Vega       Brad Silberling
# 3             Channing Tatum,Chris Pratt,Jenna Dewan          Jamie Linden
# 4                                                NaN       Cameron Cairnes
#
#                                          genre  userscore    RelDate
# 0                                  Documentary        NaN 2011-06-01
# 1  Action,Sci-Fi,Drama,Mystery,Thriller,Horror        7.7 2016-03-11
# 2                         Drama,Comedy,Romance        5.8 2006-12-01
# 3                         Drama,Comedy,Romance        6.9 2012-09-14
# 4                                Horror,Comedy        7.5 2013-06-28

# %%
df_movies['rating'] = df_movies['rating'].str.lstrip("|") # removing an "|" from the "rating" column
df_movies.head()
# Out:
#                                                  url                  title  \
# 0  https://www.metacritic.com/movie/!women-art-re...  !Women Art Revolution
# 1  https://www.metacritic.com/movie/10-cloverfiel...    10 Cloverfield Lane
# 2  https://www.metacritic.com/movie/10-items-or-less       10 Items or Less
# 3          https://www.metacritic.com/movie/10-years               10 Years
# 4  https://www.metacritic.com/movie/100-bloody-acres       100 Bloody Acres
#
#                      studio      rating  \
# 0       Hotwire Productions   Not Rated
# 1        Paramount Pictures       PG-13
# 2                Click Star           R
# 3  Anchor Bay Entertainment           R
# 4           Music Box Films   Not Rated
#
#                                                 cast              director  \
# 0                                                NaN  Lynn Hershman-Leeson
# 1  John Gallagher Jr.,John Goodman,Mary Elizabeth...      Dan Trachtenberg
# 2                 Jonah Hill,Morgan Freeman,Paz Vega       Brad Silberling
# 3             Channing Tatum,Chris Pratt,Jenna Dewan          Jamie Linden
# 4                                                NaN       Cameron Cairnes
#
#                                          genre  userscore    RelDate
# 0                                  Documentary        NaN 2011-06-01
# 1  Action,Sci-Fi,Drama,Mystery,Thriller,Horror        7.7 2016-03-11
# 2                         Drama,Comedy,Romance        5.8 2006-12-01
# 3                         Drama,Comedy,Romance        6.9 2012-09-14
# 4                                Horror,Comedy        7.5 2013-06-28

# %%
df_movies['title'] = df_movies['title'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
df_movies['studio'] = df_movies['studio'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
df_movies['cast'] = df_movies['cast'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
df_movies['director'] = df_movies['director'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)

# %%
df_movies.isnull().sum()
# Out:
# url             0
# title           0
# studio        350
# rating       1067
# cast         3702
# director       14
# genre          20
# userscore    2105
# RelDate         0
# dtype: int64

# %%
df_movies = df_movies.fillna({'studio': 'Unknown',
                               'rating': 'Not Rated',
                               'cast': 'Unknown', 
                               'director': 'Unknown',
                               'genre': 'Unknown'})
df_movies.head()
# Out:
#                                                  url                  title  \
# 0  https://www.metacritic.com/movie/!women-art-re...  !Women Art Revolution
# 1  https://www.metacritic.com/movie/10-cloverfiel...    10 Cloverfield Lane
# 2  https://www.metacritic.com/movie/10-items-or-less       10 Items or Less
# 3          https://www.metacritic.com/movie/10-years               10 Years
# 4  https://www.metacritic.com/movie/100-bloody-acres       100 Bloody Acres
#
#                      studio      rating  \
# 0       Hotwire Productions   Not Rated
# 1        Paramount Pictures       PG-13
# 2                Click Star           R
# 3  Anchor Bay Entertainment           R
# 4           Music Box Films   Not Rated
#
#                                                 cast              director  \
# 0                                            Unknown  Lynn Hershman-Leeson
# 1  John Gallagher Jr.,John Goodman,Mary Elizabeth...      Dan Trachtenberg
# 2                 Jonah Hill,Morgan Freeman,Paz Vega       Brad Silberling
# 3             Channing Tatum,Chris Pratt,Jenna Dewan          Jamie Linden
# 4                                            Unknown       Cameron Cairnes
#
#                                          genre  userscore    RelDate
# 0                                  Documentary        NaN 2011-06-01
# 1  Action,Sci-Fi,Drama,Mystery,Thriller,Horror        7.7 2016-03-11
# 2                         Drama,Comedy,Romance        5.8 2006-12-01
# 3                         Drama,Comedy,Romance        6.9 2012-09-14
# 4                                Horror,Comedy        7.5 2013-06-28

# %%
df_movies.isnull().sum()
# Out:
# url             0
# title           0
# studio          0
# rating          0
# cast            0
# director        0
# genre           0
# userscore    2105
# RelDate         0
# dtype: int64

# %%
df_movies = df_movies.fillna(value = 0)
df_movies.head()
# Out:
#                                                  url                  title  \
# 0  https://www.metacritic.com/movie/!women-art-re...  !Women Art Revolution
# 1  https://www.metacritic.com/movie/10-cloverfiel...    10 Cloverfield Lane
# 2  https://www.metacritic.com/movie/10-items-or-less       10 Items or Less
# 3          https://www.metacritic.com/movie/10-years               10 Years
# 4  https://www.metacritic.com/movie/100-bloody-acres       100 Bloody Acres
#
#                      studio      rating  \
# 0       Hotwire Productions   Not Rated
# 1        Paramount Pictures       PG-13
# 2                Click Star           R
# 3  Anchor Bay Entertainment           R
# 4           Music Box Films   Not Rated
#
#                                                 cast              director  \
# 0                                            Unknown  Lynn Hershman-Leeson
# 1  John Gallagher Jr.,John Goodman,Mary Elizabeth...      Dan Trachtenberg
# 2                 Jonah Hill,Morgan Freeman,Paz Vega       Brad Silberling
# 3             Channing Tatum,Chris Pratt,Jenna Dewan          Jamie Linden
# 4                                            Unknown       Cameron Cairnes
#
#                                          genre  userscore    RelDate
# 0                                  Documentary        0.0 2011-06-01
# 1  Action,Sci-Fi,Drama,Mystery,Thriller,Horror        7.7 2016-03-11
# 2                         Drama,Comedy,Romance        5.8 2006-12-01
# 3                         Drama,Comedy,Romance        6.9 2012-09-14
# 4                                Horror,Comedy        7.5 2013-06-28

# %%
excel_file = r'C:\Users\memwa\Desktop\cleaned_data\metaclean_cleaned.xlsx'
df_movies.to_excel(excel_file, index=False)
