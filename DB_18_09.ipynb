# %%
import psycorpg2 
import pandas as pd

# define a finction to connect to DB

def connectDB():
    conn = psycopg2.connect(
        host = 'localhost',
        database = 'onlinestore', 
        port = 5433,
        user = 'postgres',
        password ='alex2000') 
    return conn 

def getAllCustPD(conn): # has one parameter which is the connection itself - using pandas, analyse data, view something in bulk
    dfCus = pd.read_sql('SELECT * customers ORDER bycustomer_id', conn)
    return dfCus

def getAllCustSales(conn):
    dfCus = pd.read_sql('SELECT' customers.customer, SUM(sales.customer_sales), from, conn) # insert the name if the table)) - don't forget to close the connection 
    return dfCus 

def getAllCustCur(conn): # this one is more sufficient, the input is the connection, the functuion is executed by having a cursor, it will take the data one by one, a pointer that points to the data set itself 
    cur = conn.cursor() # if we want to be more effecient, changes one by at a time 
    cur.execute('SELECT * FROM customers ORDER by customer_id', conn)
    row = cur.ferchone #fetches (points) the first one
    while row is not None: # if the row is not null then print it, if yes move to the next one
        print(row)
        row = cur.fetchone() #move to the next one
cur.close()

#call the connection to connect to DB 
conn = connectDB 
print('Connection success')

# get all cutomers using pandas

dfCus = getAllCustPD(conn)
print(dfCus)

#get all customers suing cursor 
getAllCurstCur

#close the connection 
conn.close()

print ('connection closed')



# linear regression - the extent to which the dependent variable is linked to its dependent variables 
# correlation = the probality between the connection of two variables 
# say who wrote the code
# test it first on sql 
# then run mean and other descriptive statistics 


#sql 
#word document - erd in there, anticipate the future needs of the statistical analysis, and explain why the ERD is like that, and justify the foreign key and primary key and they are based on the business needs
#python

# explain your code on Friday and explain why we have the foreign and primary key in the methodology
