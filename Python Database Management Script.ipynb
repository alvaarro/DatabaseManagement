# %%
import pandas as pd
import psycopg2

# %%
dataFrame_ExpertReviews = pd.read_excel(r"C:\Users\Jaume\Documents\MDDB\Database Management\ExpertReviewsClean43LIWC.xlsx")

# %%
dataFrame_UserReviews = pd.read_excel(r"C:\Users\Jaume\Documents\MDDB\Database Management\UserReviewsClean43LIWC.xlsx")

# %%
dataFrame_MetaClean = pd.read_excel(r"C:\Users\Jaume\Documents\MDDB\Database Management\metaClean43Brightspace.xlsx")

# %%
dataFrame_Sales = pd.read_excel(r"C:\Users\Jaume\Documents\MDDB\Database Management\sales.xlsx")

# %%
cleanDataFrame_Sales = pd.DataFrame()
cleanDataFrame_Sales = dataFrame_Sales.drop(columns=['domestic_box_office','international_box_office','Unnamed: 8', 'opening_weekend','theatre_count','avg run per theatre','creative_type'])


cleanDataFrame_Sales
# Out:
#        year     release_date                                 title  \
# 0      2000      January 1st                          Bakha Satang
# 1      2001     January 12th                             Antitrust
# 2      2000     January 28th                              Santitos
# 3      2002  2002 (Wide) by                    Frank McKlusky C.I.
# 4      2002     January 25th                    A Walk to Remember
# ...     ...              ...                                   ...
# 30607  2021      January 1st                Jokbeoldu sinmun iyagi
# 30608  2021        March 5th                      My Salinger Year
# 30609  2021      January 1st                     Escort Vehicle 36
# 30610  2021         May 21st                               The Dry
# 30611  2021      January 1st  Posledniy bogatyr. KorenÃ¢â‚¬â„¢ Zla
#
#                    genre  worldwide_box_office  production_budget  runtime  \
# 0                  Drama               76576.0                NaN    129.0
# ...

# %%
cleanDataFrame_UserReviews = dataFrame_UserReviews[['url','reviewer', 'Rev']]
cleanDataFrame_UserReviews
# Out:
#                                                    url            reviewer  \
# 0             https://www.metacritic.com/movie/bronson      'Longbottom94'
# 1             https://www.metacritic.com/movie/bronson           'MartinB'
# 2             https://www.metacritic.com/movie/bronson            'Jaakko'
# 3             https://www.metacritic.com/movie/bronson             'CapoR'
# 4             https://www.metacritic.com/movie/bronson          'OrwellB.'
# ...                                                ...                 ...
# 319657  https://www.metacritic.com/movie/spirited-away           'Zenflar'
# 319658  https://www.metacritic.com/movie/spirited-away    'juiliopaublito'
# 319659  https://www.metacritic.com/movie/spirited-away   'PorridgeBoy3000'
# 319660  https://www.metacritic.com/movie/spirited-away        'jamesfhall'
# 319661  https://www.metacritic.com/movie/spirited-away          'Motoritz'
#
#                                                       Rev
# ...

# %%
cleanDataFrame_ExpertReviews = dataFrame_ExpertReviews[['url','reviewer', 'Rev']]
cleanDataFrame_ExpertReviews

#Now we add the two clean review tables and we make it one
frames = [cleanDataFrame_UserReviews,cleanDataFrame_ExpertReviews]
clean_ReviewsTable = pd.concat(frames)

clean_ReviewsTable
# Out:
#                                                    url           reviewer  \
# 0             https://www.metacritic.com/movie/bronson     'Longbottom94'
# 1             https://www.metacritic.com/movie/bronson          'MartinB'
# 2             https://www.metacritic.com/movie/bronson           'Jaakko'
# 3             https://www.metacritic.com/movie/bronson            'CapoR'
# 4             https://www.metacritic.com/movie/bronson         'OrwellB.'
# ...                                                ...                ...
# 238968  https://www.metacritic.com/movie/spirited-away   'Desson Thomson'
# 238969  https://www.metacritic.com/movie/spirited-away   'David Sterritt'
# 238970  https://www.metacritic.com/movie/spirited-away    'Wesley Morris'
# 238971  https://www.metacritic.com/movie/spirited-away   'William Arnold'
# 238972  https://www.metacritic.com/movie/spirited-away      'C.W. Nevius'
#
#                                                       Rev
# ...

# %%
#we try to connect to postgresql
con = psycopg2.connect(
   database="Movie Database",
   user="postgres",
   password="Reves360",
   host="localhost",
   port= '11940'
   )
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Untitled-1.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X16sdW50aXRsZWQ%3D?line=0'>1</a> #we try to connect to postgresql
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X16sdW50aXRsZWQ%3D?line=1'>2</a> con = psycopg2.connect(
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X16sdW50aXRsZWQ%3D?line=2'>3</a>    database="Movie Database",
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X16sdW50aXRsZWQ%3D?line=3'>4</a>    user="postgres",
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X16sdW50aXRsZWQ%3D?line=4'>5</a>    password="Reves360",
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X16sdW50aXRsZWQ%3D?line=5'>6</a>    host="localhost",
# ...
